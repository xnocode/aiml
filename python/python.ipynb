# %% [markdown]
# # Python

# %% [markdown]
# ### First Program

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World")
print("xnocode")
# Out:
# Hello World
# xnocode

# %%
print("Hello World", "xnocode")
# Out:
# Hello World xnocode

# %%
print("Hello \n World", "With Python")
# Out:
# Hello
#  World With Python

# %% [markdown]
# ### Variables

# %%
name = "xnocode"
age = 24
PI = 3.1416
print(name)
print(age, PI)
print("my name is:", name)
print("my age is:", age)
# Out:
# xnocode
# 24 3.1416
# my name is: xnocode
# my age is: 24

# %% [markdown]
# ### Indentation

# %%
if True:
  print("Hello")
  print("World")
# Out:
# Hello
# World

# %%
if True:
print("Hello")
# Out:
#   File "/tmp/ipykernel_842/3598588081.py", line 2
#     print("Hello")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# ### case-sensitive

# %%
name = "xnocode"
Name = "Ridoy"
print(name)
print(Name)
# Out:
# xnocode
# Ridoy

# %% [markdown]
# ### type() function - data types

# %%
name = "xnocode"
age = 24
PI = 3.14
isPrime = True
isNone = None
print(type(name))
print(type(age))
print(type(PI))
print(type(isPrime))
print(type(isNone))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# ### comments

# %%
# single line comment

"""
This is a multi-line comment
"""
# Out:
# '\nThis is a multi-line comment\n'
